# %%
import pandas as pd
import osmnx as ox

CIDADE = "Recife, Pernambuco, Brasil"
ARQUIVO = "bairros_vizinhos.csv"
GEO_PACKAGE = "grafo_recife.graphml"
SAIDA = "bairros_vizinhos_tratados.csv"

mapeamento_pesos = {
    "motorway": 0.8,
    "motorway_link": 0.8,
    "trunk": 1.0,
    "trunk_link": 1.0,
    "primary": 1.2,
    "primary_link": 1.2,
    "secondary": 1.5,
    "secondary_link": 1.5,
    "tertiary": 1.8,
    "tertiary_link": 1.8,
    "residential": 2.0,
    "service": 2.5,
    "living_street": 2.5,
    "pedestrian": 3.0,
    "track": 3.0,
}

tipo_normalizado = {
"motorway":	"Via expressa / Rodovia",
"motorway_link": "Alça de acesso à via expressa",
"trunk": "Via arterial / Rodovia urbana",
"trunk_link": "Acesso à via arterial",
"primary":	"Avenida principal",
"primary_link":	"Alça de acesso à avenida principal",
"secondary": "Avenida secundária	",
"secondary_link": "Ramal de ligação secundária",
"tertiary": "Rua de ligação / Coletora local",
"tertiary_link": "Trecho curto entre ruas terciárias",
"residential": "Rua local / de bairro",
"service": "Rua de serviço / interna",
"living_street": "Rua compartilhada / de pedestres",
"pedestrian": "Calçadão / rua exclusiva de pedestres",
"track": "Estrada de terra / rural",
}

def normalizar_tipo(tipo):
    if isinstance(tipo, list):
        prioridade = ["motorway", "trunk", "primary", "secondary", "tertiary", "residential", "service"]
        for p in prioridade:
            if p in tipo:
                return p
        return tipo[0]
    if "_link" in tipo:
        return tipo.replace("_link", "")
    return tipo

# %%
# === Lê os pares de bairros ===
df = pd.read_csv(ARQUIVO, sep=",")
df.head()
# Out:
#        name      neighbor
# 0   Aflitos     Rosarinho
# 1   Aflitos  Encruzilhada
# 2   Aflitos    Espinheiro
# 3   Aflitos        Graças
# 4  Jaqueira   Tamarineira

# %%
print("Carregando mapa da cidade a partir do OSM...")
G = ox.graph_from_place(CIDADE, network_type="drive")
# Out:
# Carregando mapa da cidade a partir do OSM...

# %%
import osmnx as ox
from concurrent.futures import ProcessPoolExecutor, as_completed

def processar_par(row):
    bairro_a = row["name"]
    bairro_b = row["neighbor"]

    try:
        orig_node = ox.distance.nearest_nodes(G, *ox.geocode(f"{bairro_a}, {CIDADE}")[::-1])
        dest_node = ox.distance.nearest_nodes(G, *ox.geocode(f"{bairro_b}, {CIDADE}")[::-1])

        route = ox.routing.shortest_path(G, orig_node, dest_node, weight="length")

        nome_selecionado = tipo_selecionado = id_rua = None

        for nodo_origem, nodo_destino in zip(route[:-1], route[1:]):
            atributos_aresta = G.edges[nodo_origem, nodo_destino, 0]
            nome = atributos_aresta.get("name")
            tipo = atributos_aresta.get("highway")
            osmid = atributos_aresta.get("osmid")

            if isinstance(nome, list):
                nome = nome[0]
            if isinstance(tipo, list):
                tipo = tipo[0]
            if isinstance(osmid, list):
                osmid = osmid[0]

            if nome:
                nome_selecionado = nome
                tipo_selecionado = tipo
                id_rua = osmid
                break

        if nome_selecionado is None:
            nome_selecionado = "N/A"
            tipo_selecionado = "N/A"
            id_rua = "N/A"

        return {
            "Bairro": bairro_a,
            "Vizinho": bairro_b,
            "Logradouro": nome_selecionado,
            "Tipo": tipo_selecionado,
            "Peso": mapeamento_pesos.get(normalizar_tipo(tipo_selecionado), 2.0),
            "Tipo Normalizado": tipo_normalizado.get(normalizar_tipo(tipo_selecionado), "Desconhecido"),
            "Id Rua": f"https://openstreetmap.org/way/{id_rua}",
        }

    except Exception as e:
        print(f"Erro ao processar {bairro_a}-{bairro_b}: {e}")
        return {
            "Bairro": bairro_a,
            "Vizinho": bairro_b,
            "Logradouro": "N/A",
            "Tipo": "N/A",
            "Peso": "N/A",
            "Tipo Normalizado": "N/A",
            "Id Rua": "N/A",
        }

# execução paralela
total_size = len(df)
print(f"Total de pares a processar: {total_size}")

resultados = []
with ProcessPoolExecutor() as executor:
    futures = {executor.submit(processar_par, row): i for i, row in df.iterrows()}
    for i, future in enumerate(as_completed(futures), 1):
        resultado = future.result()
        resultados.append(resultado)
        print(f"[{i}/{total_size}] {resultado['Bairro']} ↔ {resultado['Vizinho']} processado")
# Out:
# Total de pares a processar: 494
# [1/494] Jaqueira ↔ Santana processado
# [2/494] Jaqueira ↔ Tamarineira processado
# [3/494] Hipódromo ↔ Encruzilhada processado
# [4/494] Aflitos ↔ Rosarinho processado
# [5/494] Jaqueira ↔ Parnamirim processado
# [6/494] Aflitos ↔ Encruzilhada processado
# [7/494] Aflitos ↔ Graças processado
# [8/494] Jaqueira ↔ Torre processado
# [9/494] Aflitos ↔ Espinheiro processado
# [10/494] Jaqueira ↔ Graças processado
# [11/494] Hipódromo ↔ Campo Grande processado
# [12/494] Ponto de Parada ↔ Encruzilhada processado
# [13/494] Ponto de Parada ↔ Campo Grande processado
# [14/494] Ponto de Parada ↔ Arruda processado
# [15/494] Hipódromo ↔ Ponto de Parada processado
# [16/494] Rosarinho ↔ Aflitos processado
# [17/494] Ponto de Parada ↔ Rosarinho processado
# [18/494] Ponto de Parada ↔ Hipódromo processado
# [19/494] Rosarinho ↔ Ponto de Parada processado
# [20/494] Rosarinho ↔ Encruzilhada processado
# [21/494] Rosarinho ↔ Tamarineira processado
# [22/494] Tamarineira ↔ Jaqueira processado
# [23/494] Tamarineira ↔ Graças processado
# [24/494] Tamarineira ↔ Casa Amarela processado
# [25/494] Tamarineira ↔ Parnamirim processado
# [26/494] Encruzilhada ↔ Aflitos processado
# [27/494] Rosarinho ↔ Graças processado
# [28/494] Tamarineira ↔ Mangabeira processado
# [29/494] Rosarinho ↔ Arruda processado
# [30/494] Tamarineira ↔ Rosarinho processado
# [31/494] Encruzilhada ↔ Rosarinho processado
# [32/494] Tamarineira ↔ Arruda processado
# [33/494] Encruzilhada ↔ Ponto de Parada processado
# [34/494] Encruzilhada ↔ Graças processado
# [35/494] Encruzilhada ↔ Espinheiro processado
# [36/494] Encruzilhada ↔ Hipódromo processado
# [37/494] Encruzilhada ↔ Torreão processado
# [38/494] Espinheiro ↔ Encruzilhada processado
# [39/494] Encruzilhada ↔ Campo Grande processado
# [40/494] Graças ↔ Aflitos processado
# [41/494] Espinheiro ↔ Graças processado
# [42/494] Espinheiro ↔ Santo Amaro processado
# [43/494] Graças ↔ Rosarinho processado
# [44/494] Espinheiro ↔ Aflitos processado
# [45/494] Espinheiro ↔ Torreão processado
# [46/494] Espinheiro ↔ Boa Vista processado
# [47/494] Graças ↔ Jaqueira processado
# [48/494] Graças ↔ Encruzilhada processado
# [49/494] Graças ↔ Boa Vista processado
# [50/494] Graças ↔ Espinheiro processado
# [51/494] Graças ↔ Torre processado
# [52/494] Graças ↔ Tamarineira processado
# [53/494] Torreão ↔ Encruzilhada processado
# [54/494] Torreão ↔ Espinheiro processado
# [55/494] Graças ↔ Madalena processado
# [56/494] Joana Bezerra ↔ Ilha do Leite processado
# [57/494] Joana Bezerra ↔ Coelhos processado
# [58/494] Graças ↔ Derby processado
# [59/494] Torreão ↔ Santo Amaro processado
# [60/494] Joana Bezerra ↔ Paissandu processado
# [61/494] Torreão ↔ Campo Grande processado
# [62/494] Joana Bezerra ↔ Ilha do Retiro processado
# [63/494] Joana Bezerra ↔ Afogados processado
# [64/494] Bairro do Recife ↔ Santo Amaro processado
# [65/494] Bairro do Recife ↔ Campo Grande processado
# [66/494] Bairro do Recife ↔ Santo Antônio processado
# [67/494] Santo Amaro ↔ Torreão processado
# [68/494] Santo Amaro ↔ Soledade processado
# [69/494] Santo Amaro ↔ Bairro do Recife processado
# [70/494] Santo Amaro ↔ Boa Vista processado
# [71/494] Boa Vista ↔ Espinheiro processado
# [72/494] Santo Amaro ↔ Espinheiro processado
# [73/494] Santo Amaro ↔ Santo Antônio processado
# [74/494] Boa Vista ↔ Coelhos processado
# [75/494] Santo Amaro ↔ Campo Grande processado
# [76/494] Boa Vista ↔ Santo Amaro processado
# [77/494] Boa Vista ↔ Graças processado
# [78/494] Boa Vista ↔ Derby processado
# [79/494] Boa Vista ↔ Ilha do Leite processado
# [80/494] Boa Vista ↔ Paissandu processado
# [81/494] Coelhos ↔ Joana Bezerra processado
# [82/494] Boa Vista ↔ Soledade processado
# [83/494] Boa Vista ↔ Santo Antônio processado
# [84/494] Coelhos ↔ Boa Vista processado
# [85/494] Coelhos ↔ Santo Antônio processado
# [86/494] Coelhos ↔ Ilha do Leite processado
# [87/494] Derby ↔ Graças processado
# [88/494] Derby ↔ Paissandu processado
# [89/494] Derby ↔ Madalena processado
# [90/494] Ilha do Leite ↔ Joana Bezerra processado
# [91/494] Ilha do Leite ↔ Boa Vista processado
# [92/494] Derby ↔ Ilha do Retiro processado
# [93/494] Derby ↔ Boa Vista processado
# [94/494] Paissandu ↔ Joana Bezerra processado
# [95/494] Ilha do Leite ↔ Paissandu processado
# [96/494] Paissandu ↔ Boa Vista processado
# [97/494] Ilha do Leite ↔ Coelhos processado
# [98/494] Paissandu ↔ Derby processado
# [99/494] Paissandu ↔ Ilha do Leite processado
# [100/494] Santo Antônio ↔ Santo Amaro processado
# [101/494] Paissandu ↔ Ilha do Retiro processado
# [102/494] Santo Antônio ↔ Bairro do Recife processado
# [103/494] Santo Antônio ↔ Boa Vista processado
# [104/494] Afogados ↔ Joana Bezerra processado
# [105/494] Paissandu ↔ Madalena processado
# [106/494] Santo Antônio ↔ Coelhos processado
# [107/494] Soledade ↔ Santo Amaro processado
# [108/494] Soledade ↔ Boa Vista processado
# [109/494] Afogados ↔ Bongi processado
# [110/494] Afogados ↔ Mustardinha processado
# [111/494] Afogados ↔ Ilha do Retiro processado
# [112/494] Afogados ↔ Pina processado
# [113/494] Afogados ↔ Mangueira processado
# [114/494] Afogados ↔ Jiquiá processado
# [115/494] Afogados ↔ Prado processado
# [116/494] Bongi ↔ Afogados processado
# [117/494] Afogados ↔ Imbiribeira processado
# [118/494] Bongi ↔ Mustardinha processado
# [119/494] Ilha do Retiro ↔ Joana Bezerra processado
# [120/494] Ilha do Retiro ↔ Paissandu processado
# [121/494] Bongi ↔ San Martin processado
# [122/494] Bongi ↔ Prado processado
# [123/494] Brasília Teimosa ↔ Pina processado
# [124/494] Ilha do Retiro ↔ Derby processado
# [125/494] Ilha do Retiro ↔ Afogados processado
# [126/494] Ilha do Retiro ↔ Prado processado
# [127/494] Ilha do Retiro ↔ Madalena processado
# [128/494] Mangueira ↔ Afogados processado
# [129/494] Mangueira ↔ San Martin processado
# [130/494] Mustardinha ↔ Afogados processado
# [131/494] Mangueira ↔ Jiquiá processado
# [132/494] Mustardinha ↔ Bongi processado
# [133/494] Mustardinha ↔ Mangueira processado
# [134/494] Mangueira ↔ Mustardinha processado
# [135/494] Prado ↔ Ilha do Retiro processado
# [136/494] Prado ↔ Bongi processado
# [137/494] Prado ↔ San Martin processado
# [138/494] Prado ↔ Cordeiro processado
# [139/494] Prado ↔ Afogados processado
# [140/494] Prado ↔ Zumbi processado
# [141/494] Prado ↔ Madalena processado
# [142/494] Mustardinha ↔ San Martin processado
# [143/494] Boa Viagem ↔ Jordão processado
# [144/494] Boa Viagem ↔ Pina processado
# [145/494] Cohab ↔ Jordão processado
# [146/494] Cohab ↔ Ibura processado
# [147/494] Cohab ↔ Barro processado
# [148/494] Jordão ↔ Boa Viagem processado
# [149/494] Jordão ↔ Ibura processado
# [150/494] Pina ↔ Afogados processado
# [151/494] Boa Viagem ↔ Ibura processado
# [152/494] Boa Viagem ↔ Imbiribeira processado
# [153/494] Pina ↔ Boa Viagem processado
# [154/494] Pina ↔ Brasília Teimosa processado
# [155/494] Jordão ↔ Cohab processado
# [156/494] Pina ↔ Imbiribeira processado
# [157/494] Barro ↔ Cohab processado
# [158/494] Barro ↔ Ibura processado
# [159/494] Barro ↔ Jardim São Paulo processado
# [160/494] Barro ↔ Tejipió processado
# [161/494] Coqueiral ↔ Totó processado
# [162/494] Coqueiral ↔ Tejipió processado
# [163/494] Coqueiral ↔ Sancho processado
# [164/494] Sancho ↔ Tejipió processado
# [165/494] Sancho ↔ Curado processado
# [166/494] Sancho ↔ Coqueiral processado
# [167/494] Tejipió ↔ Sancho processado
# [168/494] Tejipió ↔ Barro processado
# [169/494] Tejipió ↔ Coqueiral processado
# [170/494] Sancho ↔ Totó processado
# [171/494] Tejipió ↔ Jardim São Paulo processado
# [172/494] Tejipió ↔ Curado processado
# [173/494] Totó ↔ Sancho processado
# [174/494] Totó ↔ Coqueiral processado
# [175/494] Areias ↔ Barro processado
# [176/494] Caçote ↔ Ipsep processado
# [177/494] Caçote ↔ Ibura processado
# [178/494] Caçote ↔ Areias processado
# [179/494] Areias ↔ Caçote processado
# [180/494] Totó ↔ Curado processado
# [181/494] Areias ↔ Imbiribeira processado
# [182/494] Areias ↔ Ibura processado
# [183/494] Areias ↔ Estância processado
# [184/494] Areias ↔ Ipsep processado
# [185/494] Areias ↔ Jardim São Paulo processado
# [186/494] Ibura ↔ Cohab processado
# [187/494] Areias ↔ Jiquiá processado
# [188/494] Ibura ↔ Jordão processado
# [189/494] Barro ↔ Areias processado
# [190/494] Ibura ↔ Boa Viagem processado
# [191/494] Ibura ↔ Caçote processado
# [192/494] Ibura ↔ Barro processado
# [193/494] Ibura ↔ Areias processado
# [194/494] Ibura ↔ Ipsep processado
# [195/494] Ibura ↔ Imbiribeira processado
# [196/494] Imbiribeira ↔ Afogados processado
# [197/494] Imbiribeira ↔ Pina processado
# [198/494] Imbiribeira ↔ Boa Viagem processado
# [199/494] Ipsep ↔ Caçote processado
# [200/494] Ipsep ↔ Areias processado
# [201/494] Ipsep ↔ Imbiribeira processado
# [202/494] Ipsep ↔ Ibura processado
# [203/494] Imbiribeira ↔ Areias processado
# [204/494] Imbiribeira ↔ Jiquiá processado
# [205/494] Imbiribeira ↔ Ipsep processado
# [206/494] Estância ↔ Areias processado
# [207/494] Estância ↔ Jardim São Paulo processado
# [208/494] Estância ↔ Jiquiá processado
# [209/494] Estância ↔ San Martin processado
# [210/494] Jardim São Paulo ↔ Estância processado
# [211/494] Jardim São Paulo ↔ Tejipió processado
# [212/494] Jardim São Paulo ↔ San Martin processado
# [213/494] Jardim São Paulo ↔ Curado processado
# [214/494] Jiquiá ↔ Afogados processado
# [215/494] Jiquiá ↔ Areias processado
# [216/494] Jiquiá ↔ Estância processado
# [217/494] Jiquiá ↔ Jardim São Paulo processado
# [218/494] Jiquiá ↔ Imbiribeira processado
# [219/494] Jiquiá ↔ San Martin processado
# [220/494] San Martin ↔ Bongi processado
# [221/494] San Martin ↔ Mangueira processado
# [222/494] San Martin ↔ Mustardinha processado
# [223/494] San Martin ↔ Prado processado
# [224/494] San Martin ↔ Estância processado
# [225/494] San Martin ↔ Jardim São Paulo processado
# [226/494] San Martin ↔ Jiquiá processado
# [227/494] Imbiribeira ↔ Ibura processado
# [228/494] San Martin ↔ Curado processado
# [229/494] San Martin ↔ Torrões processado
# [230/494] Jardim São Paulo ↔ Barro processado
# [231/494] San Martin ↔ Cordeiro processado
# [232/494] Curado ↔ Sancho processado
# [233/494] Jardim São Paulo ↔ Areias processado
# [234/494] Curado ↔ Jardim São Paulo processado
# [235/494] Curado ↔ Tejipió processado
# [236/494] Curado ↔ Totó processado
# [237/494] Jardim São Paulo ↔ Jiquiá processado
# [238/494] Curado ↔ San Martin processado
# [239/494] Curado ↔ Torrões processado
# [240/494] Curado ↔ Várzea processado
# [241/494] Curado ↔ Engenho do Meio processado
# [242/494] Cidade Universitária ↔ Várzea processado
# [243/494] Curado ↔ Cidade Universitária processado
# [244/494] Cidade Universitária ↔ Engenho do Meio processado
# [245/494] Cidade Universitária ↔ Curado processado
# [246/494] Cidade Universitária ↔ Iputinga processado
# [247/494] Engenho do Meio ↔ Cidade Universitária processado
# [248/494] Engenho do Meio ↔ Curado processado
# [249/494] Jiquiá ↔ Mangueira processado
# [250/494] Engenho do Meio ↔ Torrões processado
# [251/494] Engenho do Meio ↔ Cordeiro processado
# [252/494] Torrões ↔ San Martin processado
# [253/494] Caxangá ↔ Várzea processado
# [254/494] Torrões ↔ Cordeiro processado
# [255/494] Torrões ↔ Engenho do Meio processado
# [256/494] Torrões ↔ Curado processado
# [257/494] Caxangá ↔ Iputinga processado
# [258/494] Caxangá ↔ Sítio dos Pintos processado
# [259/494] Caxangá ↔ Apipucos processado
# [260/494] Várzea ↔ Curado processado
# [261/494] Arruda ↔ Rosarinho processado
# [262/494] Várzea ↔ Iputinga processado
# [263/494] Arruda ↔ Tamarineira processado
# [264/494] Várzea ↔ Caxangá processado
# [265/494] Arruda ↔ Ponto de Parada processado
# [266/494] Várzea ↔ Cidade Universitária processado
# [267/494] Arruda ↔ Campo Grande processado
# [268/494] Arruda ↔ Bomba do Hemetério processado
# [269/494] Arruda ↔ Peixinhos processado
# [270/494] Arruda ↔ Campina do Barreto processado
# [271/494] Campo Grande ↔ Hipódromo processado
# [272/494] Arruda ↔ Água Fria processado
# [273/494] Campo Grande ↔ Ponto de Parada processado
# [274/494] Campo Grande ↔ Encruzilhada processado
# [275/494] Arruda ↔ Mangabeira processado
# [276/494] Campo Grande ↔ Torreão processado
# [277/494] Campo Grande ↔ Santo Amaro processado
# [278/494] Campo Grande ↔ Arruda processado
# [279/494] Campo Grande ↔ Bairro do Recife processado
# [280/494] Campo Grande ↔ Peixinhos processado
# [281/494] Peixinhos ↔ Campina do Barreto processado
# [282/494] Cordeiro ↔ Prado processado
# [283/494] Cordeiro ↔ San Martin processado
# [284/494] Cordeiro ↔ Engenho do Meio processado
# [285/494] Cordeiro ↔ Torrões processado
# [286/494] Cordeiro ↔ Zumbi processado
# [287/494] Cordeiro ↔ Torre processado
# [288/494] Engenho do Meio ↔ Iputinga processado
# [289/494] Cordeiro ↔ Iputinga processado
# [290/494] Cordeiro ↔ Santana processado
# [291/494] Cordeiro ↔ Poço da Panela processado
# [292/494] Madalena ↔ Graças processado
# [293/494] Madalena ↔ Derby processado
# [294/494] Madalena ↔ Ilha do Retiro processado
# [295/494] Madalena ↔ Prado processado
# [296/494] Madalena ↔ Paissandu processado
# [297/494] Madalena ↔ Torre processado
# [298/494] Torre ↔ Jaqueira processado
# [299/494] Torre ↔ Graças processado
# [300/494] Torre ↔ Cordeiro processado
# [301/494] Torre ↔ Madalena processado
# [302/494] Caxangá ↔ Dois Irmãos processado
# [303/494] Zumbi ↔ Prado processado
# [304/494] Zumbi ↔ Cordeiro processado
# [305/494] Torre ↔ Santana processado
# [306/494] Zumbi ↔ Madalena processado
# [307/494] Zumbi ↔ Torre processado
# [308/494] Santana ↔ Cordeiro processado
# [309/494] Santana ↔ Jaqueira processado
# [310/494] Santana ↔ Torre processado
# [311/494] Santana ↔ Parnamirim processado
# [312/494] Santana ↔ Casa Forte processado
# [313/494] Santana ↔ Poço da Panela processado
# [314/494] Alto José do Pinho ↔ Casa Amarela processado
# [315/494] Alto José do Pinho ↔ Morro da Conceição processado
# [316/494] Alto José do Pinho ↔ Bomba do Hemetério processado
# [317/494] Alto José do Pinho ↔ Mangabeira processado
# [318/494] Alto José do Pinho ↔ Alto Santa Teresinha processado
# [319/494] Alto do Mandu ↔ Casa Amarela processado
# [320/494] Alto do Mandu ↔ Monteiro processado
# [321/494] Alto do Mandu ↔ Macaxeira processado
# [322/494] Casa Amarela ↔ Alto José do Pinho processado
# [323/494] Casa Amarela ↔ Alto do Mandu processado
# [324/494] Casa Amarela ↔ Tamarineira processado
# [325/494] Casa Amarela ↔ Casa Forte processado
# [326/494] Casa Amarela ↔ Morro da Conceição processado
# [327/494] Casa Amarela ↔ Parnamirim processado
# [328/494] Casa Amarela ↔ Poço da Panela processado
# [329/494] Casa Amarela ↔ Mangabeira processado
# [330/494] Casa Amarela ↔ Monteiro processado
# [331/494] Casa Forte ↔ Santana processado
# [332/494] Casa Forte ↔ Casa Amarela processado
# [333/494] Casa Forte ↔ Parnamirim processado
# [334/494] Iputinga ↔ Engenho do Meio processado
# [335/494] Casa Forte ↔ Poço da Panela processado
# [336/494] Iputinga ↔ Caxangá processado
# [337/494] Alto do Mandu ↔ Apipucos processado
# [338/494] Alto José do Pinho ↔ Alto José Bonifácio processado
# [339/494] Iputinga ↔ Várzea processado
# [340/494] Alto do Mandu ↔ Nova Descoberta processado
# [341/494] Iputinga ↔ Cordeiro processado
# [342/494] Casa Amarela ↔ Nova Descoberta processado
# [343/494] Iputinga ↔ Cidade Universitária processado
# [344/494] Casa Amarela ↔ Vasco da Gama processado
# [345/494] Iputinga ↔ Monteiro processado
# [346/494] Iputinga ↔ Poço da Panela processado
# [347/494] Monteiro ↔ Alto do Mandu processado
# [348/494] Iputinga ↔ Apipucos processado
# [349/494] Peixinhos ↔ Campo Grande processado
# [350/494] Peixinhos ↔ Arruda processado
# [351/494] Monteiro ↔ Casa Amarela processado
# [352/494] Monteiro ↔ Iputinga processado
# [353/494] Monteiro ↔ Apipucos processado
# [354/494] Monteiro ↔ Poço da Panela processado
# [355/494] Morro da Conceição ↔ Alto José Bonifácio processado
# [356/494] Morro da Conceição ↔ Alto José do Pinho processado
# [357/494] Morro da Conceição ↔ Casa Amarela processado
# [358/494] Parnamirim ↔ Santana processado
# [359/494] Parnamirim ↔ Jaqueira processado
# [360/494] Parnamirim ↔ Tamarineira processado
# [361/494] Parnamirim ↔ Casa Forte processado
# [362/494] Parnamirim ↔ Casa Amarela processado
# [363/494] Poço da Panela ↔ Santana processado
# [364/494] Poço da Panela ↔ Cordeiro processado
# [365/494] Poço da Panela ↔ Casa Amarela processado
# [366/494] Poço da Panela ↔ Casa Forte processado
# [367/494] Poço da Panela ↔ Monteiro processado
# [368/494] Beberibe ↔ Linha do Tiro processado
# [369/494] Poço da Panela ↔ Iputinga processado
# [370/494] Beberibe ↔ Água Fria processado
# [371/494] Morro da Conceição ↔ Vasco da Gama processado
# [372/494] Beberibe ↔ Dois Unidos processado
# [373/494] Bomba do Hemetério ↔ Alto José do Pinho processado
# [374/494] Beberibe ↔ Porto da Madeira processado
# [375/494] Bomba do Hemetério ↔ Alto Santa Teresinha processado
# [376/494] Bomba do Hemetério ↔ Água Fria processado
# [377/494] Cajueiro ↔ Porto da Madeira processado
# [378/494] Bomba do Hemetério ↔ Mangabeira processado
# [379/494] Cajueiro ↔ Fundão processado
# [380/494] Madalena ↔ Zumbi processado
# [381/494] Campina do Barreto ↔ Arruda processado
# [382/494] Bomba do Hemetério ↔ Arruda processado
# [383/494] Torre ↔ Zumbi processado
# [384/494] Campina do Barreto ↔ Peixinhos processado
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 69
#      67 with ProcessPoolExecutor() as executor:
#      68     futures = {executor.submit(processar_par, row): i for i, row in df.iterrows()}
# ---> 69     for i, future in enumerate(as_completed(futures), 1):
#      70         resultado = future.result()
#      71         resultados.append(resultado)
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     238     if wait_timeout < 0:
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#     246     finished = waiter.finished_futures
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
df_result = pd.DataFrame(resultados)
df_result.to_csv(SAIDA, index=False)
print(f"✅ Resultado salvo em {SAIDA}")
df_result.head()
# Out:
# ✅ Resultado salvo em /home/miguel/workspace/projeto_grafos/data/bairros_vizinhos_tratados.csv
#       Bairro       Vizinho              Logradouro      Tipo  Peso  \
# 0   Jaqueira        Graças    Rua Neto de Mendonça  tertiary   1.8
# 1    Aflitos  Encruzilhada  Rua Manuel de Carvalho  tertiary   1.8
# 2  Hipódromo  Encruzilhada    Rua Carlos Fernandes  tertiary   1.8
# 3  Hipódromo  Campo Grande    Rua Carlos Fernandes  tertiary   1.8
# 4   Jaqueira       Santana    Rua Neto de Mendonça  tertiary   1.8
#
#                   Tipo Normalizado                                   Id Rua  \
# 0  Rua de ligação / Coletora local  https://openstreetmap.org/way/965984036
# 1  Rua de ligação / Coletora local  https://openstreetmap.org/way/134174443
# 2  Rua de ligação / Coletora local  https://openstreetmap.org/way/140478431
# 3  Rua de ligação / Coletora local  https://openstreetmap.org/way/974688528
# 4  Rua de ligação / Coletora local  https://openstreetmap.org/way/965984036
#
#                        Comentário OSM
# 0             Specify road smoothness
# 1             Specify road smoothness
# 2  Acréscimo de nova rota cicloviária
# 3  Acréscimo de nova rota cicloviária
# 4             Specify road smoothness

# %%
bairros_finais = set(df_result['Bairro'])

bairros_originals = set(df['name'])

diferenca = bairros_originals - bairros_finais
print(len(diferenca))
for bairro in diferenca:
    print("Bairro não encontrado na primeira coluna:", bairro)
    
    
    
bairros_finais = set(df_result['Vizinho'])

bairros_originals = set(df['neighbor'])

diferenca = bairros_originals - bairros_finais
print(len(diferenca))
for bairro in diferenca:
    print("Bairro não encontrado na segunda coluna:", bairro)
# Out:
# 9
# Bairro não encontrado na primeira coluna: Ipsep
# Bairro não encontrado na primeira coluna: Soledade
# Bairro não encontrado na primeira coluna: Mangabeira
# Bairro não encontrado na primeira coluna: Poço da Panela
# Bairro não encontrado na primeira coluna: Água Fria
# Bairro não encontrado na primeira coluna: Parnamirim
# Bairro não encontrado na primeira coluna: Santo Antônio
# Bairro não encontrado na primeira coluna: Zumbi
# Bairro não encontrado na primeira coluna: Oitenta
# 16
# Bairro não encontrado na segunda coluna: Alto José do Pinho
# Bairro não encontrado na segunda coluna: Jaqueira
# Bairro não encontrado na segunda coluna: Bairro do Recife
# Bairro não encontrado na segunda coluna: Cajueiro
# Bairro não encontrado na segunda coluna: Caxangá
# Bairro não encontrado na segunda coluna: Cohab
# Bairro não encontrado na segunda coluna: Alto do Mandu
# Bairro não encontrado na segunda coluna: Aflitos
# Bairro não encontrado na segunda coluna: Hipódromo
# Bairro não encontrado na segunda coluna: Coqueiral
# Bairro não encontrado na segunda coluna: Beberibe
# Bairro não encontrado na segunda coluna: Joana Bezerra
# Bairro não encontrado na segunda coluna: Caçote
# Bairro não encontrado na segunda coluna: Brasília Teimosa
# Bairro não encontrado na segunda coluna: Córrego do Jenipapo
# Bairro não encontrado na segunda coluna: Boa Viagem

# %%
# Out:
# Versão 12 por umbraosmbr em 2024-09-30T23:57:57Z
# Changeset: 157317632
# Comentário: inclusão de area verde, correção de caminho, inclusão de casas no bairro do corrego do jenipapo, recife/PE #UMBRAOSM #Mapatona #SenamaSoftwarelivreBrasil2024
# ------------------------------------------------------------
